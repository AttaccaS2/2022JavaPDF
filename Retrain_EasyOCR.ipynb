# %% [markdown]
# <a href="https://colab.research.google.com/github/AttaccaS2/2022JavaPDF/blob/master/Retrain_EasyOCR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 ! git clone https://github.com/JaidedAI/EasyOCR.git
# Out:
# Cloning into 'EasyOCR'...
# remote: Enumerating objects: 2532, done.
# remote: Total 2532 (delta 0), reused 0 (delta 0), pack-reused 2532
# Receiving objects: 100% (2532/2532), 148.71 MiB | 23.85 MiB/s, done.
# Resolving deltas: 100% (1517/1517), done.
# Checking out files: 100% (301/301), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/EasyOCR/trainer/all_data
# Out:
# /content/EasyOCR/trainer/all_data

# %%
# !unzip /content/EasyOCR/trainer/all_data/en_train_filtered.zip
# Out:
# Archive:  /content/EasyOCR/trainer/all_data/en_train_filtered.zip
#   inflating: en_train_filtered/0.jpg
#   inflating: en_train_filtered/1.jpg
#   inflating: en_train_filtered/10.jpg
#   inflating: en_train_filtered/100.jpg
#   inflating: en_train_filtered/101.jpg
#   inflating: en_train_filtered/102.jpg
#   inflating: en_train_filtered/103.jpg
#   inflating: en_train_filtered/105.jpg
#   inflating: en_train_filtered/106.jpg
#   inflating: en_train_filtered/107.jpg
#   inflating: en_train_filtered/108.jpg
#   inflating: en_train_filtered/109.jpg
#   inflating: en_train_filtered/110.jpg
#   inflating: en_train_filtered/111.jpg
#   inflating: en_train_filtered/112.jpg
#   inflating: en_train_filtered/113.jpg
#   inflating: en_train_filtered/114.jpg
#   inflating: en_train_filtered/115.jpg
#   inflating: en_train_filtered/116.jpg
#   inflating: en_train_filtered/117.jpg
#   inflating: en_train_filtered/118.jpg
#   inflating: en_train_filtered/119.jpg
# ...

# %%
# !unzip /content/EasyOCR/trainer/all_data/en_val.zip
# Out:
# Archive:  /content/EasyOCR/trainer/all_data/en_val.zip
#   inflating: en_val/901.jpg
#   inflating: en_val/902.jpg
#   inflating: en_val/903.jpg
#   inflating: en_val/904.jpg
#   inflating: en_val/905.jpg
#   inflating: en_val/906.jpg
#   inflating: en_val/908.jpg
#   inflating: en_val/909.jpg
#   inflating: en_val/910.jpg
#   inflating: en_val/911.jpg
#   inflating: en_val/913.jpg
#   inflating: en_val/914.jpg
#   inflating: en_val/915.jpg
#   inflating: en_val/916.jpg
#   inflating: en_val/917.jpg
#   inflating: en_val/919.jpg
#   inflating: en_val/922.jpg
#   inflating: en_val/923.jpg
#   inflating: en_val/924.jpg
#   inflating: en_val/925.jpg
#   inflating: en_val/926.jpg
#   inflating: en_val/927.jpg
#   inflating: en_val/928.jpg
#   inflating: en_val/929.jpg
#   inflating: en_val/930.jpg
#   inflating: en_val/931.jpg
#   inflating: en_val/932.jpg
#   inflating: en_val/933.jpg
#   inflating: en_val/934.jpg
#   inflating: en_val/935.jpg
#   inflating: en_val/936.jpg
# ...

# %%
# import shutil
# shutil.rmtree('/content/EasyOCR/trainer/all_data/en_val')

# %%
cd ..
# Out:
# /content/EasyOCR/trainer

# %%
import os
import torch.backends.cudnn as cudnn
import yaml
from train import train
from utils import AttrDict
import pandas as pd

# %%
cudnn.benchmark = True
cudnn.deterministic = False

# %%
def get_config(file_path):
    with open(file_path, 'r', encoding="utf8") as stream:
        opt = yaml.safe_load(stream)
    opt = AttrDict(opt)
    if opt.lang_char == 'None':
        characters = ''
        for data in opt['select_data'].split('-'):
            csv_path = os.path.join(opt['train_data'], data, 'labels.csv')
            df = pd.read_csv(csv_path, sep='^([^,]+),', engine='python', usecols=['filename', 'words'], keep_default_na=False)
            all_char = ''.join(df['words'])
            characters += ''.join(set(all_char))
        characters = sorted(set(characters))
        opt.character= ''.join(characters)
    else:
        opt.character = opt.number + opt.symbol + opt.lang_char
    os.makedirs(f'./saved_models/{opt.experiment_name}', exist_ok=True)
    return opt

# %%
opt = get_config("config_files/en_filtered_config.yaml")
train(opt, amp=False)
# Out:
# Filtering the images containing characters which are not in opt.character
# Filtering the images whose label is longer than opt.batch_max_length
# --------------------------------------------------------------------------------
# dataset_root: all_data
# opt.select_data: ['en_train_filtered']
# opt.batch_ratio: ['1']
# --------------------------------------------------------------------------------
# dataset_root:    all_data	 dataset: en_train_filtered
# all_data/en_train_filtered
# sub-directory:	/en_train_filtered	 num samples: 882
# num total samples of en_train_filtered: 882 x 1.0 (total_data_usage_ratio) = 882
# num samples of en_train_filtered per batch: 32 x 1.0 (batch_ratio) = 32
# --------------------------------------------------------------------------------
# Total_batch_size: 32 = 32
# --------------------------------------------------------------------------------
# dataset_root:    all_data/en_val	 dataset: /
# all_data/en_val/
# sub-directory:	/.	 num samples: 88
# ...
